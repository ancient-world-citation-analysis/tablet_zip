# %% [markdown]
# # Download ORACC Directory ZIP Files (Google Colab version)

# %% [markdown]
# ## Author: Tiffany Lee

# %% [markdown]
# Context: Last April, I was trying to use utilities from [Computational Assyriology (Compass)](https://github.com/niekveldhuis/compass), a project by Professor Niek Veldhuis, to download datasets from various databases. What I found was that his tool uses the file paths of the [Oracc: The Open Richly Annotated Cuneiform Corpus](http://oracc.museum.upenn.edu/) database to download zip files of the datasets. With that in mind, I needed to produce a list of file paths to automate the process of downloading.
#
# This notebook seeks to explore solutions to produce a list of file paths/URLs and download the ZIP files corresponding to the items in the list.

# %% [markdown]
# # Notebook Setup

# %% [markdown]
# ## Mount Google Drive folder

# %% [markdown]
# The code snippet below is to mount Google Drive files so that we can interact with our Google Drive files using the file browser or command line. Running it will give a permissions prompt.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Use bash `pwd` command to examine the current directory.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Load Libraries

# %% [markdown]
# Next, we load the libraries needed for this notebook. There will also be code prompts below to load libraries in case any user wants to run only a portion of the notebook instead of the whole thing.

# %%
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm
import os
import ipywidgets as widgets
from zipfile import ZipFile

# %% [markdown]
# ## Create Download Directory
# Create a directory called `ORACC`. If the directory already exists, do nothing. We can change this directory according to what is needed.

# %%
import os

# %%
os.makedirs("AWCA/tablet_zip/ORACC", exist_ok = True)

# %% [markdown]
# # Obtain Zip File File Paths from [Oracc](http://oracc.museum.upenn.edu/) Projects Page

# %% [markdown]
# Before we can download, we need to know where to download the data for the projects. In the [Compass](https://github.com/niekveldhuis/compass) repository, Professor Veldhuis identified the pattern of the URLs corresponding to the ZIP files for the project data used the following format: "http://oracc.museum.upenn.edu/json/asbp.zip".
#
# I noticed that the links on the [Oracc Project List](http://oracc.museum.upenn.edu/projectlist.html) page followed the pattern in the URL provided above. I thought it would be a good idea to compile a list of project ZIP file URLs by extracting it from [Oracc Project List](http://oracc.museum.upenn.edu/projectlist.html). To do so, I found a Stack Overflow solution to extract website file paths with the `requests` and `bs4` libraries ([How to extract URLs from an HTML page in Python - Stack Overflow](https://stackoverflow.com/questions/15517483/how-to-extract-urls-from-an-html-page-in-python)).
#
# Thus, this part seeks to obtain the file paths for the ZIP files of each project linked on the ORACC Project Page to prepare for the downloads. Later, we will use the file paths to prepare formatted download URLs to download the project ZIP files.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Define `getFilePathListFromURL` Method

# %%
def getFilePath(page):
    """
    :param page: html of web page 
    :return urls or file paths in that page 
    This is a utility method for getFilePathListFromHTMLPage().
    """
    start_link = page.find("a href")
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote

def getFilePathListFromURL(source_url):
    """
    :param source_url: url of the source web page that we will extract file 
                       paths from 
    :return path_list: list of file paths in the source_url page 
    """
    response = requests.get(source_url)
    page = str(BeautifulSoup(response.content))
    path_list = []
    while True:
        path, n = getFilePath(page)
        page = page[n:]
        if path:
            path_list.append(path)
        else:
            break
    return path_list

# %% [markdown]
# Run `getFilePathListFromURL` Method

# %%
project_path_list = getFilePathListFromURL(source_url = "http://oracc.museum.upenn.edu/projectlist.html")
project_path_list
# Out:
# ['/',
#  './adsd',
#  './adsd',
#  'https://oeaw.academia.edu/ReinhardPirngruber',
#  './adsd/adart1',
#  './adsd/adart1',
#  './adsd/adart2',
#  './adsd/adart2',
#  './adsd/adart3',
#  './adsd/adart3',
#  './adsd/adart6',
#  './adsd/adart6',
#  './aemw',
#  './aemw',
#  './aemw/alalakh/idrimi',
#  './aemw/alalakh/idrimi',
#  'http://neareast.jhu.edu/bios/jacob-lauinger/',
#  './aemw/amarna',
#  './aemw/amarna',
#  './akklove',
#  './akklove',
#  'https://www.harrassowitz-verlag.de/title_961.ahtml',
#  './amgg',
#  './amgg',
#  './ario',
#  './ario',
#  ' https://www.en.ag.geschichte.uni-muenchen.de/staff/staff/heitmann-gordon/index.html',
#  'https://www.humboldt-foundation.de/web/home.html',
#  './armep',
#  './armep',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  'https://www.humboldt-foundation.de/web/home.html',
#  './arrim',
#  './arrim',
#  ' https://www.humboldt-foundation.de/web/home.html',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  './asbp',
#  './asbp',
#  './asbp/ninmed',
#  './asbp/ninmed',
#  './asbp/rlasb',
#  './asbp/rlasb',
#  './atae',
#  './atae',
#  './atae/assur',
#  './atae/assur',
#  './atae/burmarina',
#  './atae/burmarina',
#  './atae/durkatlimmu',
#  './atae/durkatlimmu',
#  './atae/durszarrukin',
#  './atae/durszarrukin',
#  './atae/guzana',
#  './atae/guzana',
#  './atae/huzirina',
#  './atae/huzirina',
#  './atae/imgurenlil',
#  './atae/imgurenlil',
#  './atae/kalhu',
#  './atae/kalhu',
#  './atae/kunalia',
#  './atae/kunalia',
#  './atae/mallanate',
#  './atae/mallanate',
#  './atae/marqasu',
#  './atae/marqasu',
#  './atae/nineveh',
#  './atae/nineveh',
#  './atae/samal',
#  './atae/samal',
#  './atae/szibaniba',
#  './atae/szibaniba',
#  './atae/tilbarsip',
#  './atae/tilbarsip',
#  './atae/tuszhan',
#  './atae/tuszhan',
#  './babcity',
#  './babcity',
#  './blms',
#  './blms',
#  'http://nes.berkeley.edu/Web_Veldhuis/index.html',
#  'http://www.neh.gov',
#  './btto',
#  './btto',
#  './cams',
#  './cams',
#  './cams/akno',
#  './cams/akno',
#  'https://www.uclpress.co.uk/collections/archaeology/products/125022',
#  './cams/anzu',
#  './cams/anzu',
#  'http://www.helsinki.fi/science/saa/saact-03.html',
#  'http://www.eisenbrauns.com/item/ANNSTANDA',
#  './cams/barutu',
#  './cams/barutu',
#  './cams/etana',
#  './cams/etana',
#  'http://www.helsinki.fi/science/saa/saact-02.html',
#  ' http://www.eisenbrauns.com/item/NOVSTANDA',
#  './cams/gkab',
#  './cams/gkab',
#  'http://oracc.museum.upenn.edu/gkab',
#  'http://www.ahrc.ac.uk',
#  './cams/ludlul',
#  './cams/ludlul',
#  'http://www.helsinki.fi/science/saa/saact-07.html',
#  'http://www.eisenbrauns.com/item/ANNLUDLUL',
#  './cams/selbi',
#  './cams/selbi',
#  './cams/tlab',
#  './cams/tlab',
#  'http://www.ucl.ac.uk/history/current-students/ug/special',
#  'http://shuilas.org/index.html',
#  'http://shuilas.org/index.html',
#  'http://akkpm.org/index.html',
#  'http://akkpm.org/index.html',
#  'http://ccp.yale.edu',
#  'http://ccp.yale.edu',
#  './cdli',
#  './cdli',
#  './ckst',
#  './ckst',
#  './cmawro',
#  './cmawro',
#  './cmawro/cmawr1',
#  './cmawro/cmawr1',
#  'https://brill.com/view/title/15358',
#  './cmawro/cmawr2',
#  './cmawro/cmawr2',
#  'https://brill.com/view/title/15359',
#  './cmawro/cmawr3',
#  './cmawro/cmawr3',
#  './cmawro/maqlu',
#  './cmawro/maqlu',
#  'https://brill.com/view/title/24515',
#  './contrib',
#  './contrib',
#  'http://http://creativecommons.org/licenses/by-sa/3.0/',
#  './contrib/amarna',
#  './contrib/amarna',
#  './contrib/lambert',
#  './contrib/lambert',
#  './ctij',
#  './ctij',
#  'www.tau.ac.il/humanities/archaeology/ancient_israel.html',
#  './dcclt',
#  './dcclt',
#  'http://www.neh.gov',
#  './dcclt/ebla',
#  './dcclt/ebla',
#  './dcclt/jena',
#  './dcclt/jena',
#  'https://www.uni-jena.de/en/Hilprecht+Collection+.html',
#  'http://ls.berkeley.edu/art-hum/HRF',
#  './dcclt/nineveh',
#  './dcclt/nineveh',
#  'http://neh.gov',
#  'http://www.britishmuseum.org',
#  './dcclt/signlists',
#  './dcclt/signlists',
#  'http://neh.gov',
#  './dccmt',
#  './dccmt',
#  './dsst',
#  './dsst',
#  'https://www.unige.ch/lettres/fr/',
#  'http://www.snf.ch/en/Pages/default.aspx',
#  './ecut',
#  './ecut',
#  'https://www.ag.geschichte.uni-muenchen.de/personen/mitarbeiter/christiansen/index.html',
#  'https://www.humboldt-foundation.de/web/home.html',
#  './epsd2',
#  './epsd2',
#  './etcsri',
#  './etcsri',
#  'http://www.otka.hu/?set_lang=991',
#  './glass',
#  './glass',
#  './hbtin',
#  './hbtin',
#  'http://berkeleyprosopography.org/',
#  './lacost',
#  './lacost',
#  './lovelyrics',
#  './lovelyrics',
#  './nere',
#  './nere',
#  './nimrud',
#  './nimrud',
#  'http://www.ahrc.ac.uk/',
#  './obel',
#  './obel',
#  './obmc',
#  './obmc',
#  './obta',
#  './obta',
#  './ogsl',
#  './ogsl',
#  './oimea',
#  './oimea',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  'https://www.humboldt-foundation.de/web/home.html',
#  './pnao',
#  './pnao',
#  './qcat',
#  './qcat',
#  './riao',
#  './riao',
#  ' https://www.humboldt-foundation.de/web/home.html',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  './ribo',
#  './ribo',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  ' https://www.humboldt-foundation.de/web/home.html',
#  './ribo/bab7scores',
#  './ribo/bab7scores',
#  './ribo/babylon10',
#  './ribo/babylon10',
#  './ribo/babylon2',
#  './ribo/babylon2',
#  './ribo/babylon3',
#  './ribo/babylon3',
#  './ribo/babylon4',
#  './ribo/babylon4',
#  './ribo/babylon5',
#  './ribo/babylon5',
#  './ribo/babylon6',
#  './ribo/babylon6',
#  './ribo/babylon7',
#  './ribo/babylon7',
#  './ribo/babylon8',
#  './ribo/babylon8',
#  './ribo/sources',
#  './ribo/sources',
#  './rimanum',
#  './rimanum',
#  'http://www.degruyter.com/view/product/181597',
#  './rinap',
#  './rinap',
#  'http://www.neh.gov',
#  './rinap/rinap1',
#  './rinap/rinap1',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-220-4.html',
#  './rinap/rinap2',
#  './rinap/rinap2',
#  'https://www.eisenbrauns.org/books/titles/978-1-64602-109-3.html',
#  './rinap/rinap3',
#  './rinap/rinap3',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-241-9.html',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-242-6.html',
#  './rinap/rinap4',
#  './rinap/rinap4',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-209-9.html',
#  './rinap/rinap5',
#  './rinap/rinap5',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-997-5.html',
#  './rinap/rinap5p1',
#  './rinap/rinap5p1',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-997-5.html',
#  './rinap/scores',
#  './rinap/scores',
#  './rinap/sources',
#  './rinap/sources',
#  './saao',
#  './saao',
#  'http://www.helsinki.fi/science/saa/saa.html',
#  'http://www.helsinki.fi/science/saa/',
#  'http://oracc.museum.upenn.edu/saao/knpp/',
#  'http://oracc.museum.upenn.edu/saao/aebp/',
#  './saao/aebp',
#  './saao/aebp',
#  'https://www.en.ag.geschichte.uni-muenchen.de/research/mocci/index.html',
#  './saao/knpp',
#  './saao/knpp',
#  './saao/saa01',
#  './saao/saa01',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-383-6.html',
#  './saao/saa02',
#  './saao/saa02',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-332-4.html',
#  './saao/saa03',
#  './saao/saa03',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-334-8.html',
#  './saao/saa04',
#  './saao/saa04',
#  './saao/saa05',
#  './saao/saa05',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-326-3.html',
#  './saao/saa06',
#  './saao/saa06',
#  './saao/saa07',
#  './saao/saa07',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-335-5.html',
#  './saao/saa08',
#  './saao/saa08',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-331-7.html',
#  './saao/saa09',
#  './saao/saa09',
#  './saao/saa10',
#  './saao/saa10',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-337-9.html ',
#  './saao/saa11',
#  './saao/saa11',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-336-2.html',
#  './saao/saa12',
#  './saao/saa12',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-338-6.html ',
#  './saao/saa13',
#  './saao/saa13',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-329-4.html',
#  './saao/saa14',
#  './saao/saa14',
#  './saao/saa15',
#  './saao/saa15',
#  './saao/saa16',
#  './saao/saa16',
#  './saao/saa17',
#  './saao/saa17',
#  './saao/saa18',
#  './saao/saa18',
#  './saao/saa19',
#  './saao/saa19',
#  'https://www.eisenbrauns.org/books/titles/978-952-10-1338-6.html',
#  './saao/saa20',
#  './saao/saa20',
#  'https://www.eisenbrauns.org/books/titles/978-952-10-1341-6.html',
#  './saao/saa21',
#  './saao/saa21',
#  'https://www.eisenbrauns.org/books/titles/978-952-10-9498-9.html',
#  './saao/saas2',
#  './saao/saas2',
#  'https://www.eisenbrauns.org/books/titles/978-1-57506-330-0.html',
#  './suhu',
#  './suhu',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  'https://www.humboldt-foundation.de/web/home.html',
#  './tcma',
#  './tcma',
#  './tsae',
#  './tsae',
#  'http://www.en.ag.geschichte.uni-muenchen.de/chairs/chair_radner/index.html',
#  'https://www.humboldt-foundation.de/web/home.html',
#  './xcat',
#  './xcat']

# %% [markdown]
# ## Formatting the File Paths

# %% [markdown]
# Now we have a list of project ZIP file paths in the [Oracc](http://oracc.museum.upenn.edu/) website. However, we will need to do some clean up and formatting to make it easier for utilties to download the files. Some observations I have made include the following:

# %% [markdown]
# (1) I noticed that the project directory itself was listed as part of the paths (`/`) but it is redundant so I will remove the first item in the list.
#
# (2) Since the download widget doesn't take relative paths and only the project names and their corresponding subproject path, I will be removing the `./` part of the paths.
#
# (3) While the website addresses with "http", "https", and "www", may be useful for metadata purposes, I think it's best to filter them out for now.
#
# (4) Removed duplicates in url_list too.

# %% [markdown]
# ### Define `FormatFilePathListForDownload()` Method

# %%
def FormatFilePathListForDownload(project_list):
  """
  :param project_list: list of project file paths 
  :return project_list_formatted: list of formatted project file paths
  """
  project_list_formatted = project_list[1:] 
  project_list_formatted = [path[2:] for path in project_list_formatted 
                            if ("http" or "www") not in path]  
  project_list_formatted = [url for n, url in enumerate(project_list_formatted) 
                           if url not in project_list_formatted[:n]]
  return project_list_formatted

# %% [markdown]
# ### Run `FormatFilePathListForDownload()` Method

# %%
project_path_list_clean = FormatFilePathListForDownload(project_path_list)
project_path_list_clean
# Out:
# ['adsd',
#  'adsd/adart1',
#  'adsd/adart2',
#  'adsd/adart3',
#  'adsd/adart6',
#  'aemw',
#  'aemw/alalakh/idrimi',
#  'aemw/amarna',
#  'akklove',
#  'amgg',
#  'ario',
#  'armep',
#  'arrim',
#  'asbp',
#  'asbp/ninmed',
#  'asbp/rlasb',
#  'atae',
#  'atae/assur',
#  'atae/burmarina',
#  'atae/durkatlimmu',
#  'atae/durszarrukin',
#  'atae/guzana',
#  'atae/huzirina',
#  'atae/imgurenlil',
#  'atae/kalhu',
#  'atae/kunalia',
#  'atae/mallanate',
#  'atae/marqasu',
#  'atae/nineveh',
#  'atae/samal',
#  'atae/szibaniba',
#  'atae/tilbarsip',
#  'atae/tuszhan',
#  'babcity',
#  'blms',
#  'btto',
#  'cams',
#  'cams/akno',
#  'cams/anzu',
#  'cams/barutu',
#  'cams/etana',
#  'cams/gkab',
#  'cams/ludlul',
#  'cams/selbi',
#  'cams/tlab',
#  'cdli',
#  'ckst',
#  'cmawro',
#  'cmawro/cmawr1',
#  'cmawro/cmawr2',
#  'cmawro/cmawr3',
#  'cmawro/maqlu',
#  'contrib',
#  'contrib/amarna',
#  'contrib/lambert',
#  'ctij',
#  'w.tau.ac.il/humanities/archaeology/ancient_israel.html',
#  'dcclt',
#  'dcclt/ebla',
#  'dcclt/jena',
#  'dcclt/nineveh',
#  'dcclt/signlists',
#  'dccmt',
#  'dsst',
#  'ecut',
#  'epsd2',
#  'etcsri',
#  'glass',
#  'hbtin',
#  'lacost',
#  'lovelyrics',
#  'nere',
#  'nimrud',
#  'obel',
#  'obmc',
#  'obta',
#  'ogsl',
#  'oimea',
#  'pnao',
#  'qcat',
#  'riao',
#  'ribo',
#  'ribo/bab7scores',
#  'ribo/babylon10',
#  'ribo/babylon2',
#  'ribo/babylon3',
#  'ribo/babylon4',
#  'ribo/babylon5',
#  'ribo/babylon6',
#  'ribo/babylon7',
#  'ribo/babylon8',
#  'ribo/sources',
#  'rimanum',
#  'rinap',
#  'rinap/rinap1',
#  'rinap/rinap2',
#  'rinap/rinap3',
#  'rinap/rinap4',
#  'rinap/rinap5',
#  'rinap/rinap5p1',
#  'rinap/scores',
#  'rinap/sources',
#  'saao',
#  'saao/aebp',
#  'saao/knpp',
#  'saao/saa01',
#  'saao/saa02',
#  'saao/saa03',
#  'saao/saa04',
#  'saao/saa05',
#  'saao/saa06',
#  'saao/saa07',
#  'saao/saa08',
#  'saao/saa09',
#  'saao/saa10',
#  'saao/saa11',
#  'saao/saa12',
#  'saao/saa13',
#  'saao/saa14',
#  'saao/saa15',
#  'saao/saa16',
#  'saao/saa17',
#  'saao/saa18',
#  'saao/saa19',
#  'saao/saa20',
#  'saao/saa21',
#  'saao/saas2',
#  'suhu',
#  'tcma',
#  'tsae',
#  'xcat']

# %% [markdown]
# ### Optional: Concatenate the list to single string instead of a list of strings

# %% [markdown]
# If we want to use some of Professor Veldhuis' [Compass](https://github.com/niekveldhuis/compass) utilities, it is helpful to have the path list be a single string.

# %%
project_path_list_clean_string = ', '.join([url for url in project_path_list_clean])
project_path_list_clean_string
# Out:
# 'adsd, adsd/adart1, adsd/adart2, adsd/adart3, adsd/adart6, aemw, aemw/alalakh/idrimi, aemw/amarna, akklove, amgg, ario, armep, arrim, asbp, asbp/ninmed, asbp/rlasb, atae, atae/assur, atae/burmarina, atae/durkatlimmu, atae/durszarrukin, atae/guzana, atae/huzirina, atae/imgurenlil, atae/kalhu, atae/kunalia, atae/mallanate, atae/marqasu, atae/nineveh, atae/samal, atae/szibaniba, atae/tilbarsip, atae/tuszhan, babcity, blms, btto, cams, cams/akno, cams/anzu, cams/barutu, cams/etana, cams/gkab, cams/ludlul, cams/selbi, cams/tlab, cdli, ckst, cmawro, cmawro/cmawr1, cmawro/cmawr2, cmawro/cmawr3, cmawro/maqlu, contrib, contrib/amarna, contrib/lambert, ctij, w.tau.ac.il/humanities/archaeology/ancient_israel.html, dcclt, dcclt/ebla, dcclt/jena, dcclt/nineveh, dcclt/signlists, dccmt, dsst, ecut, epsd2, etcsri, glass, hbtin, lacost, lovelyrics, nere, nimrud, obel, obmc, obta, ogsl, oimea, pnao, qcat, riao, ribo, ribo/bab7scores, ribo/babylon10, ribo/babylon2, ribo/babylon3, ribo/babylon4, ribo/babylon5, ribo/babylon6, ribo/babylon7, ribo/babylon8, ribo/sources, rimanum, rinap, rinap/rinap1, rinap/rinap2, rinap/rinap3, rinap/rinap4, rinap/rinap5, rinap/rinap5p1, rinap/scores, rinap/sources, saao, saao/aebp, saao/knpp, saao/saa01, saao/saa02, saao/saa03, saao/saa04, saao/saa05, saao/saa06, saao/saa07, saao/saa08, saao/saa09, saao/saa10, saao/saa11, saao/saa12, saao/saa13, saao/saa14, saao/saa15, saao/saa16, saao/saa17, saao/saa18, saao/saa19, saao/saa20, saao/saa21, saao/saas2, suhu, tcma, tsae, xcat'

# %% [markdown]
# # Download Method 1: Use [Compass](https://github.com/niekveldhuis/compass) code

# %% [markdown]
# First, let's try using the Compass method of downloading [Oracc](http://oracc.museum.upenn.edu/) project files.

# %% [markdown]
# Quoted from [compass/2_1_0_download_ORACC-JSON.ipynb](https://github.com/niekveldhuis/compass/blob/master/2_1_Data_Acquisition_ORACC/2_1_0_download_ORACC-JSON.ipynb):
#
# > For larger projects (such as [DCCLT](http://oracc.org/dcclt)) the `zip` file may be 25Mb or more. Downloading may take some time and it may be necessary to chunk the downloading process. The `iter_content()` function in the `requests` library takes care of that.
#
# > In order to show a progress bar (with `tqdm`) we need to know how large the file to be downloaded is (this value is is then fed to the `total` parameter). The http protocol provides a key `content-length` in the headers (a dictionary) that indicates file length. Not all servers provide this field - if `content-length` is not avalaible it is set to 0. With the `total` value of 0 `tqdm` will show a bar and will count the number of chunks received, but it will not indicate the degree of progress.

# %% [markdown]
# ## Define `downloadProjectsWithCompass()` Method

# %%
import requests
from tqdm.auto import tqdm

# %%
def downloadProjectsWithCompass(project_list, destination):
  """
  :param project_list: list of project file paths 
  :param destination: destination directory to put the downloaded files in
  :return download_url_list: list of formatted download links of project ZIP
                             files that were successfully download
  :return url_not_found_list: list of formatted download links of project ZIP 
                              files that failed to download
  """
  CHUNK = 1024
  download_url_list = []
  url_not_found_list = []
  for project in project_list:
      proj = project.replace('/', '-')
      url = f"http://oracc.museum.upenn.edu/json/{proj}.zip"
      #file = f'jsonzip/{proj}.zip'
      #file = f'drive/MyDrive/AWCA/tablet_zip/ORACC/{proj}.zip'
      file = f'{destination}/{proj}.zip'
      with requests.get(url, stream=True) as request:
          if request.status_code == 200:   # meaning that the file exists
              total_size = int(request.headers.get('content-length', 0))
              tqdm.write(f'Saving {url} as {file}')
              t=tqdm(total=total_size, unit='B', unit_scale=True, desc = project)
              with open(file, 'wb') as f:
                  for c in request.iter_content(chunk_size=CHUNK):
                      t.update(len(c))
                      f.write(c)
              download_url_list.append(url)
          else:
              tqdm.write(f"WARNING: {url} does not exist.")
              url_not_found_list.append(url)       
  return download_url_list, url_not_found_list

# %% [markdown]
# ## Run `downloadProjectsWithCompass()` Method

# %% [markdown]
# Use bash `ls` command to check the contents of the destination directory before running the `downloadProjectsWithCompass()` method.

# %%
# !ls drive/MyDrive/AWCA/tablet_zip/ORACC
# Out:
# unzipped

# %% [markdown]
# Set the destination directory and run the `downloadProjectsWithCompass()` method with the necessary parameters.

# %%
destination = 'drive/MyDrive/AWCA/tablet_zip/ORACC'
download_url_list, url_not_found_list = downloadProjectsWithCompass(project_path_list_clean, destination)
# Out:
# Saving http://oracc.museum.upenn.edu/json/adsd.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/adsd.zip
# adsd:   0%|          | 0.00/8.90M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/adsd-adart1.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart1.zip
# adsd/adart1:   0%|          | 0.00/5.05M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/adsd-adart2.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart2.zip
# adsd/adart2:   0%|          | 0.00/7.33M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/adsd-adart3.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart3.zip
# adsd/adart3:   0%|          | 0.00/10.6M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/adsd-adart6.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart6.zip
# adsd/adart6:   0%|          | 0.00/4.80M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/aemw.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/aemw.zip
# aemw:   0%|          | 0.00/4.80k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/aemw-alalakh-idrimi.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/aemw-alalakh-idrimi.zip
# aemw/alalakh/idrimi:   0%|          | 0.00/210k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/aemw-amarna.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/aemw-amarna.zip
# aemw/amarna:   0%|          | 0.00/4.25M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/akklove.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/akklove.zip
# akklove:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/amgg.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/amgg.zip
# amgg:   0%|          | 0.00/131k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ario.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ario.zip
# ario:   0%|          | 0.00/2.69M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/armep.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/armep.zip
# armep:   0%|          | 0.00/224M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/arrim.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/arrim.zip
# arrim:   0%|          | 0.00/6.43k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/asbp.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/asbp.zip
# asbp:   0%|          | 0.00/5.41M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/asbp-ninmed.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/asbp-ninmed.zip
# asbp/ninmed:   0%|          | 0.00/3.20M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/asbp-rlasb.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/asbp-rlasb.zip
# asbp/rlasb:   0%|          | 0.00/146k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae.zip
# atae:   0%|          | 0.00/74.9M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-assur.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-assur.zip
# atae/assur:   0%|          | 0.00/7.13M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-burmarina.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-burmarina.zip
# atae/burmarina:   0%|          | 0.00/353k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-durkatlimmu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-durkatlimmu.zip
# atae/durkatlimmu:   0%|          | 0.00/2.26M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-durszarrukin.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-durszarrukin.zip
# atae/durszarrukin:   0%|          | 0.00/230k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-guzana.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-guzana.zip
# atae/guzana:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-huzirina.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-huzirina.zip
# atae/huzirina:   0%|          | 0.00/1.53M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-imgurenlil.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-imgurenlil.zip
# atae/imgurenlil:   0%|          | 0.00/605k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-kalhu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-kalhu.zip
# atae/kalhu:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-kunalia.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-kunalia.zip
# atae/kunalia:   0%|          | 0.00/727k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-mallanate.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-mallanate.zip
# atae/mallanate:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-marqasu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-marqasu.zip
# atae/marqasu:   0%|          | 0.00/857k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-nineveh.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-nineveh.zip
# atae/nineveh:   0%|          | 0.00/56.6M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-samal.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-samal.zip
# atae/samal:   0%|          | 0.00/92.3k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-szibaniba.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-szibaniba.zip
# atae/szibaniba:   0%|          | 0.00/423k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-tilbarsip.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-tilbarsip.zip
# atae/tilbarsip:   0%|          | 0.00/267k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/atae-tuszhan.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/atae-tuszhan.zip
# atae/tuszhan:   0%|          | 0.00/427k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/babcity.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/babcity.zip
# babcity:   0%|          | 0.00/4.04M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/blms.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/blms.zip
# blms:   0%|          | 0.00/13.5M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/btto.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/btto.zip
# btto:   0%|          | 0.00/3.74M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams.zip
# cams:   0%|          | 0.00/529k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-akno.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-akno.zip
# cams/akno:   0%|          | 0.00/12.5M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-anzu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-anzu.zip
# cams/anzu:   0%|          | 0.00/629k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-barutu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-barutu.zip
# cams/barutu:   0%|          | 0.00/196k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-etana.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-etana.zip
# cams/etana:   0%|          | 0.00/196k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-gkab.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-gkab.zip
# cams/gkab:   0%|          | 0.00/29.3M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-ludlul.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-ludlul.zip
# cams/ludlul:   0%|          | 0.00/612k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-selbi.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-selbi.zip
# cams/selbi:   0%|          | 0.00/168k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cams-tlab.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cams-tlab.zip
# cams/tlab:   0%|          | 0.00/5.77M [00:00<?, ?B/s]
# WARNING: http://oracc.museum.upenn.edu/json/cdli.zip does not exist.
# Saving http://oracc.museum.upenn.edu/json/ckst.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ckst.zip
# ckst:   0%|          | 0.00/1.24M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cmawro.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro.zip
# cmawro:   0%|          | 0.00/11.9M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cmawro-cmawr1.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-cmawr1.zip
# cmawro/cmawr1:   0%|          | 0.00/6.10M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cmawro-cmawr2.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-cmawr2.zip
# cmawro/cmawr2:   0%|          | 0.00/6.09M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cmawro-cmawr3.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-cmawr3.zip
# cmawro/cmawr3:   0%|          | 0.00/3.17M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/cmawro-maqlu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-maqlu.zip
# cmawro/maqlu:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# WARNING: http://oracc.museum.upenn.edu/json/contrib.zip does not exist.
# Saving http://oracc.museum.upenn.edu/json/contrib-amarna.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/contrib-amarna.zip
# contrib/amarna:   0%|          | 0.00/4.16M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/contrib-lambert.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/contrib-lambert.zip
# contrib/lambert:   0%|          | 0.00/792 [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ctij.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ctij.zip
# ctij:   0%|          | 0.00/3.45M [00:00<?, ?B/s]
# WARNING: http://oracc.museum.upenn.edu/json/w.tau.ac.il-humanities-archaeology-ancient_israel.html.zip does not exist.
# Saving http://oracc.museum.upenn.edu/json/dcclt.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt.zip
# dcclt:   0%|          | 0.00/70.0M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/dcclt-ebla.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-ebla.zip
# dcclt/ebla:   0%|          | 0.00/2.16M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/dcclt-jena.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-jena.zip
# dcclt/jena:   0%|          | 0.00/902k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/dcclt-nineveh.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-nineveh.zip
# dcclt/nineveh:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/dcclt-signlists.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-signlists.zip
# dcclt/signlists:   0%|          | 0.00/12.2M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/dccmt.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dccmt.zip
# dccmt:   0%|          | 0.00/4.70M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/dsst.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/dsst.zip
# dsst:   0%|          | 0.00/8.71M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ecut.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ecut.zip
# ecut:   0%|          | 0.00/6.47M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/epsd2.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/epsd2.zip
# epsd2:   0%|          | 0.00/318M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/etcsri.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/etcsri.zip
# etcsri:   0%|          | 0.00/12.2M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/glass.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/glass.zip
# glass:   0%|          | 0.00/947k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/hbtin.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/hbtin.zip
# hbtin:   0%|          | 0.00/25.6M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/lacost.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/lacost.zip
# lacost:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/lovelyrics.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/lovelyrics.zip
# lovelyrics:   0%|          | 0.00/5.15k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/nere.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/nere.zip
# nere:   0%|          | 0.00/275k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/nimrud.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/nimrud.zip
# nimrud:   0%|          | 0.00/255k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/obel.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/obel.zip
# obel:   0%|          | 0.00/2.32M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/obmc.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/obmc.zip
# obmc:   0%|          | 0.00/2.72M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/obta.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/obta.zip
# obta:   0%|          | 0.00/437k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ogsl.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ogsl.zip
# ogsl:   0%|          | 0.00/216k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/oimea.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/oimea.zip
# oimea:   0%|          | 0.00/55.2M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/pnao.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/pnao.zip
# pnao:   0%|          | 0.00/129k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/qcat.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/qcat.zip
# qcat:   0%|          | 0.00/11.5M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/riao.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/riao.zip
# riao:   0%|          | 0.00/40.4M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo.zip
# ribo:   0%|          | 0.00/7.56M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-bab7scores.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-bab7scores.zip
# ribo/bab7scores:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon10.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon10.zip
# ribo/babylon10:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon2.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon2.zip
# ribo/babylon2:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon3.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon3.zip
# ribo/babylon3:   0%|          | 0.00/147k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon4.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon4.zip
# ribo/babylon4:   0%|          | 0.00/73.0k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon5.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon5.zip
# ribo/babylon5:   0%|          | 0.00/22.6k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon6.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon6.zip
# ribo/babylon6:   0%|          | 0.00/4.22M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon7.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon7.zip
# ribo/babylon7:   0%|          | 0.00/9.53M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-babylon8.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon8.zip
# ribo/babylon8:   0%|          | 0.00/294k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/ribo-sources.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-sources.zip
# ribo/sources:   0%|          | 0.00/4.13M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rimanum.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rimanum.zip
# rimanum:   0%|          | 0.00/2.94M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap.zip
# rinap:   0%|          | 0.00/21.7M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap-rinap1.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap1.zip
# rinap/rinap1:   0%|          | 0.00/3.75M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap-rinap2.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap2.zip
# rinap/rinap2:   0%|          | 0.00/9.35M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap-rinap3.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap3.zip
# rinap/rinap3:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap-rinap4.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap4.zip
# rinap/rinap4:   0%|          | 0.00/7.14M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap-rinap5.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap5.zip
# rinap/rinap5:   0%|          | 0.00/16.7M [00:00<?, ?B/s]
# WARNING: http://oracc.museum.upenn.edu/json/rinap-rinap5p1.zip does not exist.
# Saving http://oracc.museum.upenn.edu/json/rinap-scores.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-scores.zip
# rinap/scores:   0%|          | 0.00/14.4M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/rinap-sources.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-sources.zip
# rinap/sources:   0%|          | 0.00/26.7M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao.zip
# saao:   0%|          | 0.00/64.6M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-aebp.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-aebp.zip
# saao/aebp:   0%|          | 0.00/15.2M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-knpp.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-knpp.zip
# saao/knpp:   0%|          | 0.00/14.0M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa01.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa01.zip
# saao/saa01:   0%|          | 0.00/4.99M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa02.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa02.zip
# saao/saa02:   0%|          | 0.00/2.70M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa03.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa03.zip
# saao/saa03:   0%|          | 0.00/4.06M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa04.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa04.zip
# saao/saa04:   0%|          | 0.00/8.16M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa05.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa05.zip
# saao/saa05:   0%|          | 0.00/4.99M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa06.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa06.zip
# saao/saa06:   0%|          | 0.00/7.04M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa07.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa07.zip
# saao/saa07:   0%|          | 0.00/3.82M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa08.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa08.zip
# saao/saa08:   0%|          | 0.00/7.19M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa09.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa09.zip
# saao/saa09:   0%|          | 0.00/778k [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa10.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa10.zip
# saao/saa10:   0%|          | 0.00/8.77M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa11.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa11.zip
# saao/saa11:   0%|          | 0.00/3.01M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa12.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa12.zip
# saao/saa12:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa13.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa13.zip
# saao/saa13:   0%|          | 0.00/3.82M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa14.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa14.zip
# saao/saa14:   0%|          | 0.00/6.24M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa15.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa15.zip
# saao/saa15:   0%|          | 0.00/5.86M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa16.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa16.zip
# saao/saa16:   0%|          | 0.00/3.99M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa17.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa17.zip
# saao/saa17:   0%|          | 0.00/4.52M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa18.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa18.zip
# saao/saa18:   0%|          | 0.00/4.71M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa19.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa19.zip
# saao/saa19:   0%|          | 0.00/5.49M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa20.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa20.zip
# saao/saa20:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saa21.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa21.zip
# saao/saa21:   0%|          | 0.00/3.81M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/saao-saas2.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saas2.zip
# saao/saas2:   0%|          | 0.00/1.43M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/suhu.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/suhu.zip
# suhu:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/tcma.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/tcma.zip
# tcma:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/tsae.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/tsae.zip
# tsae:   0%|          | 0.00/110M [00:00<?, ?B/s]
# Saving http://oracc.museum.upenn.edu/json/xcat.zip as drive/MyDrive/AWCA/tablet_zip/ORACC/xcat.zip
# xcat:   0%|          | 0.00/6.59k [00:00<?, ?B/s]

# %% [markdown]
# ## Examine Downloaded Files in Destination Directory

# %% [markdown]
# Use bash `ls` command to check the contents of the directory after downloading.

# %%
# !ls drive/MyDrive/AWCA/tablet_zip/ORACC
# Out:
# adsd-adart1.zip		 cams-tlab.zip	      ribo-babylon8.zip
# adsd-adart2.zip		 cams.zip	      ribo-sources.zip
# adsd-adart3.zip		 ckst.zip	      ribo.zip
# adsd-adart6.zip		 cmawro-cmawr1.zip    rimanum.zip
# adsd.zip		 cmawro-cmawr2.zip    rinap-rinap1.zip
# aemw-alalakh-idrimi.zip  cmawro-cmawr3.zip    rinap-rinap2.zip
# aemw-amarna.zip		 cmawro-maqlu.zip     rinap-rinap3.zip
# aemw.zip		 cmawro.zip	      rinap-rinap4.zip
# akklove.zip		 contrib-amarna.zip   rinap-rinap5.zip
# amgg.zip		 contrib-lambert.zip  rinap-scores.zip
# ario.zip		 ctij.zip	      rinap-sources.zip
# armep.zip		 dcclt-ebla.zip       rinap.zip
# arrim.zip		 dcclt-jena.zip       saao-aebp.zip
# asbp-ninmed.zip		 dcclt-nineveh.zip    saao-knpp.zip
# asbp-rlasb.zip		 dcclt-signlists.zip  saao-saa01.zip
# asbp.zip		 dcclt.zip	      saao-saa02.zip
# atae-assur.zip		 dccmt.zip	      saao-saa03.zip
# atae-burmarina.zip	 dsst.zip	      saao-saa04.zip
# atae-durkatlimmu.zip	 ecut.zip	      saao-saa05.zip
# atae-durszarrukin.zip	 epsd2.zip	      saao-saa06.zip
# atae-guzana.zip		 etcsri.zip	      saao-saa07.zip
# atae-huzirina.zip	 glass.zip	      saao-saa08.zip
# atae-imgurenlil.zip	 hbtin.zip	      saao-saa09.zip
# atae-kalhu.zip		 lacost.zip	      saao-saa10.zip
# atae-kunalia.zip	 lovelyrics.zip       saao-saa11.zip
# atae-mallanate.zip	 nere.zip	      saao-saa12.zip
# atae-marqasu.zip	 nimrud.zip	      saao-saa13.zip
# atae-nineveh.zip	 obel.zip	      saao-saa14.zip
# atae-samal.zip		 obmc.zip	      saao-saa15.zip
# atae-szibaniba.zip	 obta.zip	      saao-saa16.zip
# atae-tilbarsip.zip	 ogsl.zip	      saao-saa17.zip
# atae-tuszhan.zip	 oimea.zip	      saao-saa18.zip
# atae.zip		 pnao.zip	      saao-saa19.zip
# babcity.zip		 qcat.zip	      saao-saa20.zip
# blms.zip		 riao.zip	      saao-saa21.zip
# btto.zip		 ribo-bab7scores.zip  saao-saas2.zip
# cams-akno.zip		 ribo-babylon10.zip   saao.zip
# cams-anzu.zip		 ribo-babylon2.zip    suhu.zip
# cams-barutu.zip		 ribo-babylon3.zip    tcma.zip
# cams-etana.zip		 ribo-babylon4.zip    tsae.zip
# cams-gkab.zip		 ribo-babylon5.zip    unzipped
# cams-ludlul.zip		 ribo-babylon6.zip    xcat.zip
# cams-selbi.zip		 ribo-babylon7.zip

# %% [markdown]
# Examine the successful download URLs.

# %%
download_url_list
# Out:
# ['http://oracc.museum.upenn.edu/json/adsd.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart1.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart2.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart3.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart6.zip',
#  'http://oracc.museum.upenn.edu/json/aemw.zip',
#  'http://oracc.museum.upenn.edu/json/aemw-alalakh-idrimi.zip',
#  'http://oracc.museum.upenn.edu/json/aemw-amarna.zip',
#  'http://oracc.museum.upenn.edu/json/akklove.zip',
#  'http://oracc.museum.upenn.edu/json/amgg.zip',
#  'http://oracc.museum.upenn.edu/json/ario.zip',
#  'http://oracc.museum.upenn.edu/json/armep.zip',
#  'http://oracc.museum.upenn.edu/json/arrim.zip',
#  'http://oracc.museum.upenn.edu/json/asbp.zip',
#  'http://oracc.museum.upenn.edu/json/asbp-ninmed.zip',
#  'http://oracc.museum.upenn.edu/json/asbp-rlasb.zip',
#  'http://oracc.museum.upenn.edu/json/atae.zip',
#  'http://oracc.museum.upenn.edu/json/atae-assur.zip',
#  'http://oracc.museum.upenn.edu/json/atae-burmarina.zip',
#  'http://oracc.museum.upenn.edu/json/atae-durkatlimmu.zip',
#  'http://oracc.museum.upenn.edu/json/atae-durszarrukin.zip',
#  'http://oracc.museum.upenn.edu/json/atae-guzana.zip',
#  'http://oracc.museum.upenn.edu/json/atae-huzirina.zip',
#  'http://oracc.museum.upenn.edu/json/atae-imgurenlil.zip',
#  'http://oracc.museum.upenn.edu/json/atae-kalhu.zip',
#  'http://oracc.museum.upenn.edu/json/atae-kunalia.zip',
#  'http://oracc.museum.upenn.edu/json/atae-mallanate.zip',
#  'http://oracc.museum.upenn.edu/json/atae-marqasu.zip',
#  'http://oracc.museum.upenn.edu/json/atae-nineveh.zip',
#  'http://oracc.museum.upenn.edu/json/atae-samal.zip',
#  'http://oracc.museum.upenn.edu/json/atae-szibaniba.zip',
#  'http://oracc.museum.upenn.edu/json/atae-tilbarsip.zip',
#  'http://oracc.museum.upenn.edu/json/atae-tuszhan.zip',
#  'http://oracc.museum.upenn.edu/json/babcity.zip',
#  'http://oracc.museum.upenn.edu/json/blms.zip',
#  'http://oracc.museum.upenn.edu/json/btto.zip',
#  'http://oracc.museum.upenn.edu/json/cams.zip',
#  'http://oracc.museum.upenn.edu/json/cams-akno.zip',
#  'http://oracc.museum.upenn.edu/json/cams-anzu.zip',
#  'http://oracc.museum.upenn.edu/json/cams-barutu.zip',
#  'http://oracc.museum.upenn.edu/json/cams-etana.zip',
#  'http://oracc.museum.upenn.edu/json/cams-gkab.zip',
#  'http://oracc.museum.upenn.edu/json/cams-ludlul.zip',
#  'http://oracc.museum.upenn.edu/json/cams-selbi.zip',
#  'http://oracc.museum.upenn.edu/json/cams-tlab.zip',
#  'http://oracc.museum.upenn.edu/json/ckst.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-cmawr1.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-cmawr2.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-cmawr3.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-maqlu.zip',
#  'http://oracc.museum.upenn.edu/json/contrib-amarna.zip',
#  'http://oracc.museum.upenn.edu/json/contrib-lambert.zip',
#  'http://oracc.museum.upenn.edu/json/ctij.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-ebla.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-jena.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-nineveh.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-signlists.zip',
#  'http://oracc.museum.upenn.edu/json/dccmt.zip',
#  'http://oracc.museum.upenn.edu/json/dsst.zip',
#  'http://oracc.museum.upenn.edu/json/ecut.zip',
#  'http://oracc.museum.upenn.edu/json/epsd2.zip',
#  'http://oracc.museum.upenn.edu/json/etcsri.zip',
#  'http://oracc.museum.upenn.edu/json/glass.zip',
#  'http://oracc.museum.upenn.edu/json/hbtin.zip',
#  'http://oracc.museum.upenn.edu/json/lacost.zip',
#  'http://oracc.museum.upenn.edu/json/lovelyrics.zip',
#  'http://oracc.museum.upenn.edu/json/nere.zip',
#  'http://oracc.museum.upenn.edu/json/nimrud.zip',
#  'http://oracc.museum.upenn.edu/json/obel.zip',
#  'http://oracc.museum.upenn.edu/json/obmc.zip',
#  'http://oracc.museum.upenn.edu/json/obta.zip',
#  'http://oracc.museum.upenn.edu/json/ogsl.zip',
#  'http://oracc.museum.upenn.edu/json/oimea.zip',
#  'http://oracc.museum.upenn.edu/json/pnao.zip',
#  'http://oracc.museum.upenn.edu/json/qcat.zip',
#  'http://oracc.museum.upenn.edu/json/riao.zip',
#  'http://oracc.museum.upenn.edu/json/ribo.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-bab7scores.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon10.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon2.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon3.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon4.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon5.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon6.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon7.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon8.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-sources.zip',
#  'http://oracc.museum.upenn.edu/json/rimanum.zip',
#  'http://oracc.museum.upenn.edu/json/rinap.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap1.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap2.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap3.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap4.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap5.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-scores.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-sources.zip',
#  'http://oracc.museum.upenn.edu/json/saao.zip',
#  'http://oracc.museum.upenn.edu/json/saao-aebp.zip',
#  'http://oracc.museum.upenn.edu/json/saao-knpp.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa01.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa02.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa03.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa04.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa05.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa06.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa07.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa08.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa09.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa10.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa11.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa12.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa13.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa14.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa15.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa16.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa17.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa18.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa19.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa20.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa21.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saas2.zip',
#  'http://oracc.museum.upenn.edu/json/suhu.zip',
#  'http://oracc.museum.upenn.edu/json/tcma.zip',
#  'http://oracc.museum.upenn.edu/json/tsae.zip',
#  'http://oracc.museum.upenn.edu/json/xcat.zip']

# %% [markdown]
# Examine the failed download URLs.

# %%
url_not_found_list
# Out:
# ['http://oracc.museum.upenn.edu/json/cdli.zip',
#  'http://oracc.museum.upenn.edu/json/contrib.zip',
#  'http://oracc.museum.upenn.edu/json/w.tau.ac.il-humanities-archaeology-ancient_israel.html.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap5p1.zip']

# %% [markdown]
# # Download Method 2: Download using Stack Overflow code

# %% [markdown]
# Using the links generated from some modified [Compass](https://github.com/niekveldhuis/compass) code from the above method, we can obtain the download links to the project ZIP files.
#
# I found a solution from Stack Overflow using the `os` and `requests` libraries to perform this process: [Download file from URL and save it in a folder Python - Stack Overflow](https://stackoverflow.com/questions/56950987/download-file-from-url-and-save-it-in-a-folder-python).

# %% [markdown]
# ### Define `downloadProjectsWithStackOverflow()` Method and associated utility methods

# %%
import os
from tqdm.auto import tqdm
import requests

# %%
def getDownloadURL(file_path):
  """
  :param file: a file path
  :return url: a formatted download URL
  :return url_exists: True if a url exists, False if a url doesn't exist
  This is a utility method for getDownloadURLList() to prepare a formatted
  download URL.
  """
  file = file_path.replace('/', '-')
  url = f"http://oracc.museum.upenn.edu/json/{file}.zip"
  url_exists = False
  with requests.get(url, stream=True) as request:
    if request.status_code == 200:   # meaning that the file exists
      print(f"SUCCESS: {url} exists.")
      url_exists = True
    else:
      print(f"WARNING: {url} does not exist.")
      url_exists = False
  return url, url_exists

# %%
def getDownloadURLList(file_path_list):
  """
  :param file_path_list: list of file paths 
  :return download_url_list: list of formatted download links of project ZIP
                             files that were successfully download
  :return url_not_found_list: list of formatted download links of project ZIP 
                              files that failed to download
  This is a utility method for downloadProjectsWithStackOverflow() to
  prepare a list of URLs to download the project ZIP files.
  """
  download_url_list = []
  url_not_found_list = []
  for file_path in file_path_list:
    url, url_exists = getDownloadURL(file_path)
    if url_exists:
      download_url_list.append(url)
    else:
      url_not_found_list.append(url)    
  return download_url_list, url_not_found_list

# %%
def downloadFile(url: str, destination: str):
#    if not os.path.exists(destination):
#        os.makedirs(destination)  # create folder if it does not exist
    """
    :param url: URL of file to download 
    :param destination: destination directory to put the downloaded files in
    This is a utility method for downloadProjectsWithStackOverflow() to 
    download a single file given a URL and a destination directory path.
    """
    filename = url.split('/')[-1].replace(" ", "_")  # be careful with file names
    file_path = os.path.join(destination, filename)

    r = requests.get(url, stream=True)
    if r.ok:
        print("saving to", os.path.abspath(file_path))
        with open(file_path, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024 * 8):
                if chunk:
                    f.write(chunk)
                    f.flush()
                    os.fsync(f.fileno())
    else:  # HTTP status code 4XX/5XX
        print("Download failed: status code {}\n{}".format(r.status_code, r.text))

# %%
def downloadProjectsWithStackOverflow(project_list, destination):
  """
  :param project_list: list of project file paths 
  :param destination: destination directory to put the downloaded files in
  :return download_url_list: list of formatted download links of project ZIP
                             files that were successfully download
  :return url_not_found_list: list of formatted download links of project ZIP 
                              files that failed to download
  """
  download_url_list, url_not_found_list = getDownloadURLList(project_list)
  for url in download_url_list:
    downloadFile(url, destination)
  return download_url_list, url_not_found_list

# %% [markdown]
# ## Run `downloadProjectsWithStackOverflow()` Method

# %% [markdown]
# Use bash `ls` command to check the contents of the destination directory before running the `downloadProjectsWithStackOverflow()` method.

# %%
# !ls /content/drive/MyDrive/AWCA/tablet_zip/ORACC
# Out:
# unzipped

# %%
destination = "drive/MyDrive/AWCA/tablet_zip/ORACC"
download_url_list, url_not_found_list = downloadProjectsWithStackOverflow(project_path_list_clean, destination)
# Out:
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/adsd-adart6.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/aemw.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/aemw-alalakh-idrimi.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/aemw-amarna.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/akklove.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/amgg.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ario.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/armep.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/arrim.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/asbp.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/asbp-ninmed.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/asbp-rlasb.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-assur.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-burmarina.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-durkatlimmu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-durszarrukin.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-guzana.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-huzirina.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-imgurenlil.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-kalhu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-kunalia.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-mallanate.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-marqasu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-nineveh.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-samal.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-szibaniba.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-tilbarsip.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/atae-tuszhan.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/babcity.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/blms.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/btto.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-akno.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-anzu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-barutu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-etana.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-gkab.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-ludlul.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-selbi.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cams-tlab.zip exists.
# WARNING: http://oracc.museum.upenn.edu/json/cdli.zip does not exist.
# SUCCESS: http://oracc.museum.upenn.edu/json/ckst.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-cmawr1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-cmawr2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-cmawr3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/cmawro-maqlu.zip exists.
# WARNING: http://oracc.museum.upenn.edu/json/contrib.zip does not exist.
# SUCCESS: http://oracc.museum.upenn.edu/json/contrib-amarna.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/contrib-lambert.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ctij.zip exists.
# WARNING: http://oracc.museum.upenn.edu/json/w.tau.ac.il-humanities-archaeology-ancient_israel.html.zip does not exist.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-ebla.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-jena.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-nineveh.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dcclt-signlists.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dccmt.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/dsst.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ecut.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/epsd2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/etcsri.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/glass.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/hbtin.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/lacost.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/lovelyrics.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/nere.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/nimrud.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/obel.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/obmc.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/obta.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ogsl.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/oimea.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/pnao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/qcat.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/riao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-bab7scores.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon10.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon4.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon5.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon6.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon7.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-babylon8.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/ribo-sources.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rimanum.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap1.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap3.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap4.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-rinap5.zip exists.
# WARNING: http://oracc.museum.upenn.edu/json/rinap-rinap5p1.zip does not exist.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-scores.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/rinap-sources.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-aebp.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-knpp.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa01.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa02.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa03.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa04.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa05.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa06.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa07.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa08.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa09.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa10.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa11.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa12.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa13.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa14.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa15.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa16.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa17.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa18.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa19.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa20.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saa21.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/saao-saas2.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/suhu.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/tcma.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/tsae.zip exists.
# SUCCESS: http://oracc.museum.upenn.edu/json/xcat.zip exists.
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/adsd.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart1.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart2.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart3.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart6.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/aemw.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/aemw-alalakh-idrimi.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/aemw-amarna.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/akklove.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/amgg.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ario.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/armep.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/arrim.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/asbp.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/asbp-ninmed.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/asbp-rlasb.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-assur.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-burmarina.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-durkatlimmu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-durszarrukin.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-guzana.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-huzirina.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-imgurenlil.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-kalhu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-kunalia.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-mallanate.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-marqasu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-nineveh.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-samal.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-szibaniba.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-tilbarsip.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/atae-tuszhan.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/babcity.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/blms.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/btto.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-akno.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-anzu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-barutu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-etana.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-gkab.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-ludlul.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-selbi.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cams-tlab.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ckst.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-cmawr1.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-cmawr2.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-cmawr3.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/cmawro-maqlu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/contrib-amarna.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/contrib-lambert.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ctij.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-ebla.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-jena.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-nineveh.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dcclt-signlists.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dccmt.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/dsst.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ecut.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/epsd2.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/etcsri.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/glass.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/hbtin.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/lacost.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/lovelyrics.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/nere.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/nimrud.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/obel.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/obmc.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/obta.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ogsl.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/oimea.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/pnao.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/qcat.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/riao.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-bab7scores.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon10.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon2.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon3.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon4.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon5.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon6.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon7.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-babylon8.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/ribo-sources.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rimanum.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap1.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap2.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap3.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap4.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-rinap5.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-scores.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/rinap-sources.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-aebp.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-knpp.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa01.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa02.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa03.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa04.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa05.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa06.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa07.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa08.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa09.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa10.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa11.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa12.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa13.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa14.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa15.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa16.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa17.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa18.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa19.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa20.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saa21.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/saao-saas2.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/suhu.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/tcma.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/tsae.zip
# saving to /content/drive/MyDrive/AWCA/tablet_zip/ORACC/xcat.zip

# %% [markdown]
# ## Examine the Downloaded Files in the Destination Directory

# %% [markdown]
# Use bash `ls` command to check if we downloaded the files we needed.

# %%
# !ls /content/drive/MyDrive/AWCA/tablet_zip/ORACC
# Out:
# adsd-adart1.zip		 cams-tlab.zip	      ribo-babylon8.zip
# adsd-adart2.zip		 cams.zip	      ribo-sources.zip
# adsd-adart3.zip		 ckst.zip	      ribo.zip
# adsd-adart6.zip		 cmawro-cmawr1.zip    rimanum.zip
# adsd.zip		 cmawro-cmawr2.zip    rinap-rinap1.zip
# aemw-alalakh-idrimi.zip  cmawro-cmawr3.zip    rinap-rinap2.zip
# aemw-amarna.zip		 cmawro-maqlu.zip     rinap-rinap3.zip
# aemw.zip		 cmawro.zip	      rinap-rinap4.zip
# akklove.zip		 contrib-amarna.zip   rinap-rinap5.zip
# amgg.zip		 contrib-lambert.zip  rinap-scores.zip
# ario.zip		 ctij.zip	      rinap-sources.zip
# armep.zip		 dcclt-ebla.zip       rinap.zip
# arrim.zip		 dcclt-jena.zip       saao-aebp.zip
# asbp-ninmed.zip		 dcclt-nineveh.zip    saao-knpp.zip
# asbp-rlasb.zip		 dcclt-signlists.zip  saao-saa01.zip
# asbp.zip		 dcclt.zip	      saao-saa02.zip
# atae-assur.zip		 dccmt.zip	      saao-saa03.zip
# atae-burmarina.zip	 dsst.zip	      saao-saa04.zip
# atae-durkatlimmu.zip	 ecut.zip	      saao-saa05.zip
# atae-durszarrukin.zip	 epsd2.zip	      saao-saa06.zip
# atae-guzana.zip		 etcsri.zip	      saao-saa07.zip
# atae-huzirina.zip	 glass.zip	      saao-saa08.zip
# atae-imgurenlil.zip	 hbtin.zip	      saao-saa09.zip
# atae-kalhu.zip		 lacost.zip	      saao-saa10.zip
# atae-kunalia.zip	 lovelyrics.zip       saao-saa11.zip
# atae-mallanate.zip	 nere.zip	      saao-saa12.zip
# atae-marqasu.zip	 nimrud.zip	      saao-saa13.zip
# atae-nineveh.zip	 obel.zip	      saao-saa14.zip
# atae-samal.zip		 obmc.zip	      saao-saa15.zip
# atae-szibaniba.zip	 obta.zip	      saao-saa16.zip
# atae-tilbarsip.zip	 ogsl.zip	      saao-saa17.zip
# atae-tuszhan.zip	 oimea.zip	      saao-saa18.zip
# atae.zip		 pnao.zip	      saao-saa19.zip
# babcity.zip		 qcat.zip	      saao-saa20.zip
# blms.zip		 riao.zip	      saao-saa21.zip
# btto.zip		 ribo-bab7scores.zip  saao-saas2.zip
# cams-akno.zip		 ribo-babylon10.zip   saao.zip
# cams-anzu.zip		 ribo-babylon2.zip    suhu.zip
# cams-barutu.zip		 ribo-babylon3.zip    tcma.zip
# cams-etana.zip		 ribo-babylon4.zip    tsae.zip
# cams-gkab.zip		 ribo-babylon5.zip    unzipped
# cams-ludlul.zip		 ribo-babylon6.zip    xcat.zip
# cams-selbi.zip		 ribo-babylon7.zip

# %% [markdown]
# Examine the successful download URLs.

# %%
download_url_list
# Out:
# ['http://oracc.museum.upenn.edu/json/adsd.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart1.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart2.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart3.zip',
#  'http://oracc.museum.upenn.edu/json/adsd-adart6.zip',
#  'http://oracc.museum.upenn.edu/json/aemw.zip',
#  'http://oracc.museum.upenn.edu/json/aemw-alalakh-idrimi.zip',
#  'http://oracc.museum.upenn.edu/json/aemw-amarna.zip',
#  'http://oracc.museum.upenn.edu/json/akklove.zip',
#  'http://oracc.museum.upenn.edu/json/amgg.zip',
#  'http://oracc.museum.upenn.edu/json/ario.zip',
#  'http://oracc.museum.upenn.edu/json/armep.zip',
#  'http://oracc.museum.upenn.edu/json/arrim.zip',
#  'http://oracc.museum.upenn.edu/json/asbp.zip',
#  'http://oracc.museum.upenn.edu/json/asbp-ninmed.zip',
#  'http://oracc.museum.upenn.edu/json/asbp-rlasb.zip',
#  'http://oracc.museum.upenn.edu/json/atae.zip',
#  'http://oracc.museum.upenn.edu/json/atae-assur.zip',
#  'http://oracc.museum.upenn.edu/json/atae-burmarina.zip',
#  'http://oracc.museum.upenn.edu/json/atae-durkatlimmu.zip',
#  'http://oracc.museum.upenn.edu/json/atae-durszarrukin.zip',
#  'http://oracc.museum.upenn.edu/json/atae-guzana.zip',
#  'http://oracc.museum.upenn.edu/json/atae-huzirina.zip',
#  'http://oracc.museum.upenn.edu/json/atae-imgurenlil.zip',
#  'http://oracc.museum.upenn.edu/json/atae-kalhu.zip',
#  'http://oracc.museum.upenn.edu/json/atae-kunalia.zip',
#  'http://oracc.museum.upenn.edu/json/atae-mallanate.zip',
#  'http://oracc.museum.upenn.edu/json/atae-marqasu.zip',
#  'http://oracc.museum.upenn.edu/json/atae-nineveh.zip',
#  'http://oracc.museum.upenn.edu/json/atae-samal.zip',
#  'http://oracc.museum.upenn.edu/json/atae-szibaniba.zip',
#  'http://oracc.museum.upenn.edu/json/atae-tilbarsip.zip',
#  'http://oracc.museum.upenn.edu/json/atae-tuszhan.zip',
#  'http://oracc.museum.upenn.edu/json/babcity.zip',
#  'http://oracc.museum.upenn.edu/json/blms.zip',
#  'http://oracc.museum.upenn.edu/json/btto.zip',
#  'http://oracc.museum.upenn.edu/json/cams.zip',
#  'http://oracc.museum.upenn.edu/json/cams-akno.zip',
#  'http://oracc.museum.upenn.edu/json/cams-anzu.zip',
#  'http://oracc.museum.upenn.edu/json/cams-barutu.zip',
#  'http://oracc.museum.upenn.edu/json/cams-etana.zip',
#  'http://oracc.museum.upenn.edu/json/cams-gkab.zip',
#  'http://oracc.museum.upenn.edu/json/cams-ludlul.zip',
#  'http://oracc.museum.upenn.edu/json/cams-selbi.zip',
#  'http://oracc.museum.upenn.edu/json/cams-tlab.zip',
#  'http://oracc.museum.upenn.edu/json/ckst.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-cmawr1.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-cmawr2.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-cmawr3.zip',
#  'http://oracc.museum.upenn.edu/json/cmawro-maqlu.zip',
#  'http://oracc.museum.upenn.edu/json/contrib-amarna.zip',
#  'http://oracc.museum.upenn.edu/json/contrib-lambert.zip',
#  'http://oracc.museum.upenn.edu/json/ctij.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-ebla.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-jena.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-nineveh.zip',
#  'http://oracc.museum.upenn.edu/json/dcclt-signlists.zip',
#  'http://oracc.museum.upenn.edu/json/dccmt.zip',
#  'http://oracc.museum.upenn.edu/json/dsst.zip',
#  'http://oracc.museum.upenn.edu/json/ecut.zip',
#  'http://oracc.museum.upenn.edu/json/epsd2.zip',
#  'http://oracc.museum.upenn.edu/json/etcsri.zip',
#  'http://oracc.museum.upenn.edu/json/glass.zip',
#  'http://oracc.museum.upenn.edu/json/hbtin.zip',
#  'http://oracc.museum.upenn.edu/json/lacost.zip',
#  'http://oracc.museum.upenn.edu/json/lovelyrics.zip',
#  'http://oracc.museum.upenn.edu/json/nere.zip',
#  'http://oracc.museum.upenn.edu/json/nimrud.zip',
#  'http://oracc.museum.upenn.edu/json/obel.zip',
#  'http://oracc.museum.upenn.edu/json/obmc.zip',
#  'http://oracc.museum.upenn.edu/json/obta.zip',
#  'http://oracc.museum.upenn.edu/json/ogsl.zip',
#  'http://oracc.museum.upenn.edu/json/oimea.zip',
#  'http://oracc.museum.upenn.edu/json/pnao.zip',
#  'http://oracc.museum.upenn.edu/json/qcat.zip',
#  'http://oracc.museum.upenn.edu/json/riao.zip',
#  'http://oracc.museum.upenn.edu/json/ribo.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-bab7scores.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon10.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon2.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon3.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon4.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon5.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon6.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon7.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-babylon8.zip',
#  'http://oracc.museum.upenn.edu/json/ribo-sources.zip',
#  'http://oracc.museum.upenn.edu/json/rimanum.zip',
#  'http://oracc.museum.upenn.edu/json/rinap.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap1.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap2.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap3.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap4.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap5.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-scores.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-sources.zip',
#  'http://oracc.museum.upenn.edu/json/saao.zip',
#  'http://oracc.museum.upenn.edu/json/saao-aebp.zip',
#  'http://oracc.museum.upenn.edu/json/saao-knpp.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa01.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa02.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa03.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa04.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa05.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa06.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa07.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa08.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa09.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa10.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa11.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa12.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa13.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa14.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa15.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa16.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa17.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa18.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa19.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa20.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saa21.zip',
#  'http://oracc.museum.upenn.edu/json/saao-saas2.zip',
#  'http://oracc.museum.upenn.edu/json/suhu.zip',
#  'http://oracc.museum.upenn.edu/json/tcma.zip',
#  'http://oracc.museum.upenn.edu/json/tsae.zip',
#  'http://oracc.museum.upenn.edu/json/xcat.zip']

# %% [markdown]
# Examine the failed download URLs.

# %%
url_not_found_list
# Out:
# ['http://oracc.museum.upenn.edu/json/cdli.zip',
#  'http://oracc.museum.upenn.edu/json/contrib.zip',
#  'http://oracc.museum.upenn.edu/json/w.tau.ac.il-humanities-archaeology-ancient_israel.html.zip',
#  'http://oracc.museum.upenn.edu/json/rinap-rinap5p1.zip']

# %% [markdown]
# # Unzip Files

# %% [markdown]
# After we downloaded all of the ZIP files, the next step may be to unzip and examine its contents.
#
# I recently learned about a library called `zipfile` that handles this step from this website: [Python unzip: How To Extract Single or Multiple Files](https://appdividend.com/2022/01/19/python-unzip/).
#
# Below we will define some methods that will help to unzip project files.

# %%
from zipfile import ZipFile

# %% [markdown]
# ## Create Unzipped Files Directory
# Create a directory called `unzipped`. If the directory already exists, do nothing. We can change this directory according to what is needed.

# %%
os.makedirs("drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped", exist_ok = True)

# %% [markdown]
# ## Define `unzipFile()` Method

# %% [markdown]
# This is a method that unzips a single file.

# %%
def unzipFile(file, source_directory, destination):
  """
  :param file: ZIP file name
  :param source_directory: source directory of the ZIP file
  :param destination: destination directory to put the downloaded files in
  This is a method that unzips a single file. Utility for `unzipMultipleFiles().`
  """
  if not source_directory.endswith("/"):
    source_directory = source_directory + "/"
  if not destination.endswith("/"):
    destination = destination + "/"
  file_path = source_directory + file
  print(file_path)
  file_name = file[:file.rfind(".zip")]
  with ZipFile(file_path, "r") as zipObj:
      zipObj.extractall(f"{destination}{file_name}")
  file_name = file[:file.rfind(".zip")]
  print(f'Unzipped {file}. See {destination}{file_name}.')

# %% [markdown]
# ### Run `unzipFile() Method`

# %% [markdown]
# We will use the `adsd-adart1.zip` as an example to run this `unzipFile()` method.

# %%
unzipFile("adsd-adart1.zip", "drive/MyDrive/AWCA/tablet_zip/ORACC", "drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped")
# Out:
# drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart1.zip
# Unzipped adsd-adart1.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart1.

# %% [markdown]
# Use bash `ls` command with option `-R` to get a recursive directory listing of the unzipped file.

# %%
# !ls -R drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart1/
# Out:
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart1/:
# adsd
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart1/adsd:
# adart1
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart1/adsd/adart1:
# adsd-adart1-portal.json  corpus.json	 index-cat.json  index-txt.json
# catalogue.json		 gloss-akk.json  index-lem.json  metadata.json
# cat.geojson		 gloss-qpn.json  index-qpn.json  sortcodes.json
# corpusjson		 index-akk.json  index-tra.json
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart1/adsd/adart1/corpusjson:
# X102611.json  X102831.json  X103090.json  X103430.json	X103753.json
# X102612.json  X102832.json  X103210.json  X103460.json	X103780.json
# X102613.json  X102840.json  X103221.json  X103570.json	X103790.json
# X102620.json  X102861.json  X103222.json  X103610.json	X103801.json
# X102630.json  X102862.json  X103223.json  X103661.json	X103802.json
# X102640.json  X102870.json  X103224.json  X103670.json	X103811.json
# X102661.json  X102880.json  X103241.json  X103680.json	X103812.json
# X102662.json  X102890.json  X103242.json  X103690.json	X103813.json
# X102701.json  X102910.json  X103280.json  X103700.json	X103820.json
# X102702.json  X102930.json  X103291.json  X103721.json	X103840.json
# X102731.json  X102940.json  X103292.json  X103722.json	X103910.json
# X102732.json  X102990.json  X103301.json  X103723.json	X104181.json
# X102760.json  X103000.json  X103321.json  X103724.json	X104182.json
# X102770.json  X103010.json  X103322.json  X103725.json	X104530.json
# X102781.json  X103020.json  X103330.json  X103731.json	X104630.json
# X102782.json  X103071.json  X103380.json  X103732.json	X105670.json
# X102811.json  X103072.json  X103421.json  X103751.json	X106510.json
# X102812.json  X103080.json  X103422.json  X103752.json

# %% [markdown]
# ## Define `unzipMultipleFiles()` Method

# %% [markdown]
# This is a method that unzips multiple given files.

# %%
def unzipFile(file, source_directory, destination):
  """
  :param file: ZIP file name
  :param source_directory: source directory of the ZIP file
  :param destination: destination directory to put the downloaded files in
  This is a method that unzips a single file. Utility for unzipMultipleFiles().
  """
  if not source_directory.endswith("/"):
    source_directory = source_directory + "/"
  if not destination.endswith("/"):
    destination = destination + "/"
  file_path = source_directory + file
  print(file_path)
  file_name = file[:file.rfind(".zip")]
  with ZipFile(file_path, "r") as zipObj:
      zipObj.extractall(f"{destination}{file_name}")
  file_name = file[:file.rfind(".zip")]
  print(f'Unzipped {file}. See {destination}{file_name}.')

# %%
def unzipMultipleFiles(file_list, source_directory, destination):
  """
  :param file: ZIP file name
  :param source_directory: source directory of the ZIP file
  :param destination: destination directory to put the downloaded files in
  This is a method that unzips multiple files. Uses unzipFile().
  """
  if not source_directory.endswith("/"):
    source_directory = source_directory + ("/")
  if not destination.endswith("/"):
    destination = destination + "/"
  for file in file_list:
    try:
        unzipFile(file, source_directory, destination)
    except (FileNotFoundError, IOError):
        print("File not found. Wrong file path.")

# %% [markdown]
# ### Run `unzipMultipleFiles()` Method

# %% [markdown]
# We will use the `file_list` as an example to run this `unzipMultipleFiles()` method.

# %%
file_list = ['adsd-adart2.zip', 'adsd-adart3.zip', 'cams-tlab.zip', 'cams.zip', 
             'cdli.zip', 'ckst.zip', 'ribo.zip']
source_directory = "drive/MyDrive/AWCA/tablet_zip/ORACC"
destination = "drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped"
unzipMultipleFiles(file_list, source_directory, destination)
# Out:
# drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart2.zip
# Unzipped adsd-adart2.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart2.
# drive/MyDrive/AWCA/tablet_zip/ORACC/adsd-adart3.zip
# Unzipped adsd-adart3.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart3.
# drive/MyDrive/AWCA/tablet_zip/ORACC/cams-tlab.zip
# Unzipped cams-tlab.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/cams-tlab.
# drive/MyDrive/AWCA/tablet_zip/ORACC/cams.zip
# Unzipped cams.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/cams.
# drive/MyDrive/AWCA/tablet_zip/ORACC/cdli.zip
# File not found. Wrong file path.
# drive/MyDrive/AWCA/tablet_zip/ORACC/ckst.zip
# Unzipped ckst.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/ckst.
# drive/MyDrive/AWCA/tablet_zip/ORACC/ribo.zip
# Unzipped ribo.zip. See drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/ribo.

# %% [markdown]
# Use bash `ls` command with option `-R` to get a recursive directory listing of the unzipped files.

# %%
# !ls -R drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart2/
# Out:
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart2/:
# adsd
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart2/adsd:
# adart2
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart2/adsd/adart2:
# adsd-adart2-portal.json  corpus.json	 index-cat.json  index-txt.json
# catalogue.json		 gloss-akk.json  index-lem.json  metadata.json
# cat.geojson		 gloss-qpn.json  index-qpn.json  sortcodes.json
# corpusjson		 index-akk.json  index-tra.json
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/adsd-adart2/adsd/adart2/corpusjson:
# X201641.json  X201770.json  X201880.json  X202001.json	X202270.json
# X201642.json  X201781.json  X201891.json  X202002.json	X202291.json
# X201650.json  X201782.json  X201892.json  X202011.json	X202292.json
# X201661.json  X201783.json  X201893.json  X202012.json	X202300.json
# X201662.json  X201784.json  X201901.json  X202013.json	X202304.json
# X201671.json  X201791.json  X201902.json  X202014.json	X202320.json
# X201672.json  X201792.json  X201903.json  X202021.json	X202340.json
# X201681.json  X201793.json  X201904.json  X202022.json	X202370.json
# X201682.json  X201794.json  X201905.json  X202030.json	X202380.json
# X201683.json  X201795.json  X201911.json  X202041.json	X202390.json
# X201684.json  X201801.json  X201912.json  X202042.json	X202400.json
# X201685.json  X201802.json  X201921.json  X202043.json	X202410.json
# X201690.json  X201803.json  X201922.json  X202071.json	X202420.json
# X201701.json  X201804.json  X201923.json  X202072.json	X202451.json
# X201702.json  X201810.json  X201931.json  X202080.json	X202452.json
# X201703.json  X201821.json  X201932.json  X202091.json	X202460.json
# X201704.json  X201822.json  X201933.json  X202092.json	X202470.json
# X201705.json  X201823.json  X201934.json  X202093.json	X202480.json
# X201706.json  X201831.json  X201941.json  X202094.json	X202491.json
# X201707.json  X201832.json  X201942.json  X202095.json	X202492.json
# X201708.json  X201833.json  X201951.json  X202100.json	X202510.json
# X201709.json  X201834.json  X201952.json  X202111.json	X202530.json
# X201711.json  X201835.json  X201953.json  X202112.json	X202540.json
# X201712.json  X201841.json  X201954.json  X202121.json	X202551.json
# X201713.json  X201842.json  X201955.json  X202122.json	X202552.json
# X201714.json  X201851.json  X201971.json  X202130.json	X202560.json
# X201715.json  X201852.json  X201972.json  X202140.json	X202571.json
# X201731.json  X201861.json  X201981.json  X202180.json	X202572.json
# X201732.json  X201862.json  X201982.json  X202210.json	X202590.json
# X201751.json  X201863.json  X201983.json  X202220.json	X202600.json
# X201752.json  X201864.json  X201984.json  X202250.json
# X201761.json  X201871.json  X201991.json  X202261.json
# X201762.json  X201872.json  X201992.json  X202262.json

# %%
# !ls -R drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/ribo/
# Out:
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/ribo/:
# ribo
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/ribo/ribo:
# catalogue.json	gloss-sux-x-emesal.json  index-tra.json
# cat.geojson	index-akk.json		 index-txt.json
# corpusjson	index-cat.json		 metadata.json
# corpus.json	index-lem.json		 ribo-portal.json
# gloss-akk.json	index-qpn.json		 sortcodes.json
# gloss-qpn.json	index-sux.json
# gloss-sux.json	index-sux-x-emesal.json
#
# drive/MyDrive/AWCA/tablet_zip/ORACC/unzipped/ribo/ribo/corpusjson:
